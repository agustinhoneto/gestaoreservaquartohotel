# %%
from services.chart_service import ChartService
ChartService().show_chart()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 from services.chart_service import ChartService
# ----> 2 ChartService().show_chart()
#
# File /workspaces/room-booking-app-facens/services/chart_service.py:61, in ChartService.show_chart(self)
#      59 check_in_date = reservations_df['check_in_date'].min()
#      60 check_out_date = reservations_df['check_out_date'].max()
# ---> 61 date_range = pd.date_range(start=check_in_date, end=check_out_date)
#      63 availability_data = []
#      65 for hotel_name in hotels_df['name']:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/datetimes.py:1008, in date_range(start, end, periods, freq, tz, normalize, name, inclusive, unit, **kwargs)
#    1005 if freq is None and com.any_none(periods, start, end):
#    1006     freq = "D"
# -> 1008 dtarr = DatetimeArray._generate_range(
# ...
